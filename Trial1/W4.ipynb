# %%
import pandas as pd
import numpy as np
import re
from sklearn.impute import SimpleImputer

# %%
pd.set_option("display.max_rows", None)  
pd.set_option("display.max_columns", None)
pd.set_option("display.precision", 2)

# %%
df1 = pd.read_csv("ecommerce_customer_data_custom_ratios.csv")
df1.head()
# Out:
#    Customer ID        Purchase Date Product Category  Product Price  Quantity  \
# 0        46251  2020-09-08 09:38:32      Electronics             12         3
# 1        46251  2022-03-05 12:56:35             Home            468         4
# 2        46251  2022-05-23 18:18:01             Home            288         2
# 3        46251  2020-11-12 13:13:29         Clothing            196         1
# 4        13593  2020-11-27 17:55:11             Home            449         1
#
#    Total Purchase Amount Payment Method  Customer Age  Returns  \
# 0                    740    Credit Card            37      0.0
# 1                   2739         PayPal            37      0.0
# 2                   3196         PayPal            37      0.0
# 3                   3509         PayPal            37      0.0
# 4                   3452    Credit Card            49      0.0
#
#          Customer Name  Age  Gender  Churn
# 0  Christine Hernandez   37    Male      0
# ...

# %%
df2 = pd.read_csv("ecommerce_customer_data_large.csv")
df2.head()
# Out:
#    Customer ID        Purchase Date Product Category  Product Price  Quantity  \
# 0        44605  2023-05-03 21:30:02             Home            177         1
# 1        44605  2021-05-16 13:57:44      Electronics            174         3
# 2        44605  2020-07-13 06:16:57            Books            413         1
# 3        44605  2023-01-17 13:14:36      Electronics            396         3
# 4        44605  2021-05-01 11:29:27            Books            259         4
#
#    Total Purchase Amount Payment Method  Customer Age  Returns Customer Name  \
# 0                   2427         PayPal            31      1.0   John Rivera
# 1                   2448         PayPal            31      1.0   John Rivera
# 2                   2345    Credit Card            31      1.0   John Rivera
# 3                    937           Cash            31      0.0   John Rivera
# 4                   2598         PayPal            31      1.0   John Rivera
#
#    Age  Gender  Churn
# ...

# %%
df1.describe()
# Out:
#        Customer ID  Product Price   Quantity  Total Purchase Amount  \
# count    250000.00      250000.00  250000.00              250000.00
# mean      25004.04         254.66       3.00                2725.37
# std       14428.28         141.57       1.41                1442.93
# min           1.00          10.00       1.00                 100.00
# 25%       12497.75         132.00       2.00                1477.00
# 50%       25018.00         255.00       3.00                2724.00
# 75%       37506.00         377.00       4.00                3974.00
# max       50000.00         500.00       5.00                5350.00
#
#        Customer Age   Returns        Age     Churn
# count     250000.00  202404.0  250000.00  250000.0
# mean          43.94       0.5      43.94       0.2
# std           15.35       0.5      15.35       0.4
# min           18.00       0.0      18.00       0.0
# 25%           31.00       0.0      31.00       0.0
# ...

# %%
df2.describe()
# Out:
#        Customer ID  Product Price   Quantity  Total Purchase Amount  \
# count    250000.00      250000.00  250000.00              250000.00
# mean      25017.63         254.74       3.00                2725.39
# std       14412.52         141.74       1.41                1442.58
# min           1.00          10.00       1.00                 100.00
# 25%       12590.00         132.00       2.00                1476.00
# 50%       25011.00         255.00       3.00                2725.00
# 75%       37441.25         377.00       4.00                3975.00
# max       50000.00         500.00       5.00                5350.00
#
#        Customer Age   Returns        Age     Churn
# count     250000.00  202618.0  250000.00  250000.0
# mean          43.80       0.5      43.80       0.2
# std           15.36       0.5      15.36       0.4
# min           18.00       0.0      18.00       0.0
# 25%           30.00       0.0      30.00       0.0
# ...

# %%
df1.rename(columns={"Customer ID":"Customer_ID"}, inplace=True)
df1.rename(columns={"Purchase Date":"Purchase_Date"}, inplace=True)
df1.rename(columns={"Product Price":"Product_Price"}, inplace=True)
df1.rename(columns={"Total Purchase Amount":"Total_Purchase_Amount"}, inplace=True)
df1.rename(columns={"Payment Method":"Payment_Method"}, inplace=True)
df1.rename(columns={"Customer Age":"Customer_Age"}, inplace=True)
df1.rename(columns={"Customer Name":"Customer_Name"}, inplace=True)

# %%
df1.head()
# Out:
#    Customer_ID        Purchase_Date Product Category  Product_Price  Quantity  \
# 0        46251  2020-09-08 09:38:32      Electronics             12         3
# 1        46251  2022-03-05 12:56:35             Home            468         4
# 2        46251  2022-05-23 18:18:01             Home            288         2
# 3        46251  2020-11-12 13:13:29         Clothing            196         1
# 4        13593  2020-11-27 17:55:11             Home            449         1
#
#    Total_Purchase_Amount Payment_Method  Customer_Age  Returns  \
# 0                    740    Credit Card            37      0.0
# 1                   2739         PayPal            37      0.0
# 2                   3196         PayPal            37      0.0
# 3                   3509         PayPal            37      0.0
# 4                   3452    Credit Card            49      0.0
#
#          Customer_Name  Age  Gender  Churn
# 0  Christine Hernandez   37    Male      0
# ...

# %%
df2.rename(columns={"Customer ID":"Customer_ID"}, inplace=True)
df2.rename(columns={"Purchase Date":"Purchase_Date"}, inplace=True)
df2.rename(columns={"Product Price":"Product_Price"}, inplace=True)
df2.rename(columns={"Total Purchase Amount":"Total_Purchase_Amount"}, inplace=True)
df2.rename(columns={"Payment Method":"Payment_Method"}, inplace=True)
df2.rename(columns={"Customer Age":"Customer_Age"}, inplace=True)
df2.rename(columns={"Customer Name":"Customer_Name"}, inplace=True)

# %%
df2.head()
# Out:
#    Customer_ID        Purchase_Date Product Category  Product_Price  Quantity  \
# 0        44605  2023-05-03 21:30:02             Home            177         1
# 1        44605  2021-05-16 13:57:44      Electronics            174         3
# 2        44605  2020-07-13 06:16:57            Books            413         1
# 3        44605  2023-01-17 13:14:36      Electronics            396         3
# 4        44605  2021-05-01 11:29:27            Books            259         4
#
#    Total_Purchase_Amount Payment_Method  Customer_Age  Returns Customer_Name  \
# 0                   2427         PayPal            31      1.0   John Rivera
# 1                   2448         PayPal            31      1.0   John Rivera
# 2                   2345    Credit Card            31      1.0   John Rivera
# 3                    937           Cash            31      0.0   John Rivera
# 4                   2598         PayPal            31      1.0   John Rivera
#
#    Age  Gender  Churn
# ...

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=250000, step=1)

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=250000, step=1)

# %%
merged_df = pd.merge(df1, df2, on="Customer_ID", how="outer")

# %%
merged_df.head()
# Out:
#    Customer_ID      Purchase_Date_x Product Category_x  Product_Price_x  \
# 0        46251  2020-09-08 09:38:32        Electronics             12.0
# 1        46251  2020-09-08 09:38:32        Electronics             12.0
# 2        46251  2020-09-08 09:38:32        Electronics             12.0
# 3        46251  2020-09-08 09:38:32        Electronics             12.0
# 4        46251  2020-09-08 09:38:32        Electronics             12.0
#
#    Quantity_x  Total_Purchase_Amount_x Payment_Method_x  Customer_Age_x  \
# 0         3.0                    740.0      Credit Card            37.0
# 1         3.0                    740.0      Credit Card            37.0
# 2         3.0                    740.0      Credit Card            37.0
# 3         3.0                    740.0      Credit Card            37.0
# 4         3.0                    740.0      Credit Card            37.0
#
#    Returns_x      Customer_Name_x  Age_x Gender_x  Churn_x  \
# ...

# %%
merged_df.head()
# Out:
#    Customer_ID      Purchase_Date_x Product Category_x  Product_Price_x  \
# 0        46251  2020-09-08 09:38:32        Electronics             12.0
# 1        46251  2020-09-08 09:38:32        Electronics             12.0
# 2        46251  2020-09-08 09:38:32        Electronics             12.0
# 3        46251  2020-09-08 09:38:32        Electronics             12.0
# 4        46251  2020-09-08 09:38:32        Electronics             12.0
#
#    Quantity_x  Total_Purchase_Amount_x Payment_Method_x  Customer_Age_x  \
# 0         3.0                    740.0      Credit Card            37.0
# 1         3.0                    740.0      Credit Card            37.0
# 2         3.0                    740.0      Credit Card            37.0
# 3         3.0                    740.0      Credit Card            37.0
# 4         3.0                    740.0      Credit Card            37.0
#
#    Returns_x      Customer_Name_x  Age_x Gender_x  Churn_x  \
# ...
